# %% [markdown]
# # One-Account HANK Model with SRL
#
# One-asset heterogeneous agent New Keynesian model (SRL Section 4.3). Households have **endogenous labour supply**; budget: $c_t + b_{t+1} = (1+r_t)b_t + w_t y_t n_t + d_t - T_t$, $b\geq 0$.
#
# **Policy (consumption, labour):** $(c, n) = \pi(b, y; r, w)$ — depend on **prices** $(r, w)$ (and dividend $d_t$, tax $T_t$). SRL uses **gradient-stop** on $(r, w)$ so households take prices as given.
#
# **Prices and aggregates:**
# - **$r$ and $w$ are not random:** They are solved from **aggregate market clearing** (see below). We use an outer loop / solver to find $(r_t, w_t)$ that clear bond and labour markets; those prices are then fed into the policy with stop-gradient.
# - **Bond market clearing:** $\int b\, dG = B$ (discrete: $\sum_j b_j \, d_j = B$). Aggregate household bond holdings equal government bond supply $B$.
# - **Government budget:** $B\, r_t = T_t$ — tax revenue equals interest on debt; tax $T_t$ is then borne by individuals (lump-sum in the baseline).
# - **Firm dividend (to individuals):** Aggregate dividend is $D_t = (1 - w_t/z_t)Y_t - \frac{\theta}{2}\Pi_t^2 Y_t$. Each individual receives this dividend (e.g. per capita if mass 1); they also pay tax $T_t$. So disposable income includes wage $w_t y_t n_t$, dividend $d_t$, minus tax $T_t$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

np.random.seed(42)
plt.rcParams['font.size'] = 10
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## Calibration (SRL Table 6, Appendix A.3)
#
# - **Preferences:** $\beta=0.975$, CRRA in consumption $\sigma=1$, separable labor with Frisch $1/\eta$, $\eta=1$.
# - **Taylor rule:** $1+i_{t+1} = \bar{R}\, (1+\pi_t)^\phi\, e^{\varepsilon_t}$ with $\phi=1.5$, $\bar{R}=1.025$; monetary shock $e^{\varepsilon_t}$ (AR(1) $\rho_e=0.9$, $\nu_e=0.002$). **Fisher:** $1+r_t = (1+i_t)/(1+\pi_t)$ so real rate $r_t$ in the budget.
# - **Aggregate TFP** $z_t$: $\rho_z=0.9$, $\nu_z=0.07$.
# - **Idiosyncratic** $y$: same as Huggett (log AR(1), 3 states).
# - **Bonds:** $b\geq 0$, fixed supply $B$; government $r_t B = T_t$.

# %%
beta = 0.975
sigma = 1.0
eta = 1.0       # inverse Frisch elasticity
phi_taylor = 1.5
R_bar = 1.025
rho_z, nu_z = 0.9, 0.07
rho_e, nu_e = 0.9, 0.002
rho_y, nu_y = 0.6, 0.2
ny = 3
B_supply = 10.0   # fixed bond supply
b_min = 0.0
b_max = 100.0
nb = 200
nz = 50
ne = 50
nr, r_min, r_max = 30, 0.01, 0.04
nw, w_min, w_max = 30, 0.7, 1.0
c_min = 1e-3
n_min = 1e-4
T_trunc = 90

# NK block (for Y_t and Phillips curve penalty)
epsilon = 6.0          # elasticity of substitution across goods
theta_rotemberg = 0.1  # Rotemberg cost (inflation cost and Phillips curve)
penalty_phillips = 1e4 # weight on Phillips curve residual in loss (high = enforce PC)

print("One-account HANK calibration (SRL 4.3, Table 6):")
print(f"  β={beta}, σ={sigma}, η={eta}, R̄={R_bar}, φ={phi_taylor}")
print(f"  ρz={rho_z}, νz={nu_z}; ρe={rho_e}, νe={nu_e}")

# %%
def tauchen_ar1(rho, sigma_innov, n_states, m=3):
    sigma_x = sigma_innov / np.sqrt(1 - rho**2)
    x_min, x_max = -m * sigma_x, m * sigma_x
    x_grid = np.linspace(x_min, x_max, n_states)
    step = (x_max - x_min) / (n_states - 1)
    P = np.zeros((n_states, n_states))
    for i in range(n_states):
        for j in range(n_states):
            if j == 0:
                P[i, j] = norm.cdf((x_grid[j] - rho * x_grid[i] + step / 2) / sigma_innov)
            elif j == n_states - 1:
                P[i, j] = 1 - norm.cdf((x_grid[j] - rho * x_grid[i] - step / 2) / sigma_innov)
            else:
                P[i, j] = (norm.cdf((x_grid[j] - rho * x_grid[i] + step / 2) / sigma_innov)
                           - norm.cdf((x_grid[j] - rho * x_grid[i] - step / 2) / sigma_innov))
    P = P / P.sum(axis=1, keepdims=True)
    return x_grid, P

log_y_grid, Ty = tauchen_ar1(rho_y, nu_y, ny)
y_grid = np.exp(log_y_grid)
invariant_y = np.linalg.matrix_power(Ty.T, 200)[:, 0]
y_grid = y_grid / (y_grid @ invariant_y)

log_z_grid, Tz = tauchen_ar1(rho_z, nu_z, nz)
z_grid = np.exp(log_z_grid)
e_grid, Te = tauchen_ar1(rho_e, nu_e, ne)

b_grid = np.linspace(b_min, b_max, nb)
r_grid = np.linspace(r_min, r_max, nr)
w_grid = np.linspace(w_min, w_max, nw)

def u_separable(c, n):
    """u(c,n) = c^(1-σ)/(1-σ) - n^(1+η)/(1+η)."""
    c = np.maximum(c, c_min)
    n = np.maximum(np.minimum(n, 10.0), n_min)
    if np.abs(sigma - 1) < 1e-10:
        uc = np.log(c)
    else:
        uc = (c ** (1 - sigma)) / (1 - sigma)
    un = -(n ** (1 + eta)) / (1 + eta)
    return uc + un

print("y_grid:", y_grid)
print("z_grid (first/last):", z_grid[0], z_grid[-1])

# %% [markdown]
# ## Full NK structure: r, w from market clearing; Y_t; bond/tax/dividend; Phillips curve penalty
#
# - **r, w are not random:** They are determined by **aggregate market clearing**. We use an **outer loop** (or root-finder) to solve for $(r_t, w_t)$ such that (i) bond market clears and (ii) labour market clears; those prices are then fed into the policy with **stop-gradient** so individuals take $(r_t, w_t)$ as given.
# - **Bond market clearing:** $\sum_j b_j \, d_j = B$ (aggregate household bond holdings = government bond supply $B$). In the code we solve for $(r,w)$ so that current (or next-period) aggregate bond demand equals $B$.
# - **Government budget / tax:** $B\, r_t = T_t$ — tax revenue equals interest on debt; individuals pay this tax (e.g. lump-sum $T_t$ per capita).
# - **Firm dividend to individuals:** Aggregate dividend is $D_t = (1 - w_t/z_t)Y_t - \frac{\theta}{2}\Pi_t^2 Y_t$. Individuals receive $d_t = D_t$ (per capita); budget is $c + b' = (1+r)b + w y n + d_t - T_t$.
# - **Output from resource constraint (Rotemberg):** $Y_t = C_t + \frac{\theta}{2}\Pi_t^2 Y_t$ $\Rightarrow$ $Y_t = C_t / (1 - \frac{\theta}{2}\Pi_t^2)$ with $C_t = \int c_t\, dG$.
# - **Fisher equation (nominal vs real rate):** The **real** gross rate in the household budget is $1+r_t = (1+R_t)/(1+\pi_t)$, where $R_t$ (or $1+i_t$) is the **nominal gross rate**. So $1+r_t = (1+i_t)/(1+\pi_t)$; the real rate $r_t$ is used in $c + b' = (1+r_t)b_t + \ldots$.
# - **Taylor rule (nominal rate):** The nominal gross rate is set by $1 + i_{t+1} = \bar{R}\, (1+\pi_t)^\phi\, e^{\varepsilon_t}$, where $\bar{R}$ is steady-state nominal gross rate, $\phi$ the Taylor coefficient on inflation, and $e^{\varepsilon_t}$ the **monetary policy shock** (random). So $R_t^{\text{nom}} = \bar{R}(1+\pi_t)^\phi e^{\varepsilon_t}$; then real gross $1+r_t = R_t^{\text{nom}}/(1+\pi_t)$.
# - **NK Phillips curve as penalty:** We add the Phillips curve **quadratic residual** to the loss with **high penalty** so the equilibrium approximately satisfies:
#   $$\Pi_t(1+\Pi_t) = \frac{\varepsilon}{\theta}\left(\frac{w_t}{z_t} - \frac{\varepsilon-1}{\varepsilon}\right) + \frac{Y_{t+1}}{Y_t}\cdot\frac{\Pi_{t+1}(1+\Pi_{t+1})}{1+R_t}.$$
#   Here $1+R_t$ is the nominal gross rate (from Taylor rule). Residual $R_{PC} = \text{LHS} - \text{RHS}$; we add $\lambda_{PC}\, R_{PC}^2$ to the loss (with $\lambda_{PC}$ large).

# %% [markdown]
# ## Simplified price process (placeholder when market clearing is off)
#
# In the full model, $(r_t, w_t)$ are solved from **market clearing** ($\sum b\, dG = B$ and labour demand = supply); $T_t = r_t B$; $d_t = (1-w_t/z_t)Y_t - \frac{\theta}{2}\Pi_t^2 Y_t$. When we do **not** run the market-clearing solver (e.g. for a quick test), we use a simplified law of motion: $r_t$, $w_t$ follow exogenous AR(1)-like processes and $T_t = r_t B$, $d_t = \bar{d}\, z_t$.

# %%
r_ss = R_bar - 1.0
w_ss = 0.85
d_ss = 0.1

def prices_next(r_t, w_t, z_idx, e_idx, Tz, Te, z_grid, e_grid):
    """Simplified: r, w mean-revert and are shocked by z, e. T = r*B."""
    z_val = z_grid[z_idx]
    e_val = e_grid[e_idx]
    r_next = 0.7 * r_t + 0.2 * r_ss + 0.02 * (z_val - 1) + 0.01 * e_val
    w_next = 0.7 * w_t + 0.2 * w_ss + 0.15 * (z_val - 1)
    r_next = np.clip(r_next, r_min, r_max)
    w_next = np.clip(w_next, w_min, w_max)
    T_next = r_next * B_supply
    d_next = d_ss * z_val
    return r_next, w_next, T_next, d_next

def policy_placeholder(b, y, r, w, d, T, c_frac=0.6, n_frac=0.5):
    """Placeholder: consume c_frac of cash-on-hand, work n_frac. Cash = (1+r)b + w*y*n + d - T."""
    n = np.full_like(b, np.clip(n_frac, n_min, 2.0))
    cash = (1 + r) * b + w * y * n + d - T
    c = np.maximum(c_frac * cash, c_min)
    b_next = np.clip(cash - c, b_min, b_max)
    return c, b_next, n

def draw_next_state(y_idx, z_idx, e_idx, Ty, Tz, Te):
    """Draw (y, z, e)_{t+1} indices from transition matrices (same idea as Huggett/K-S)."""
    y_next = np.random.choice(Ty.shape[1], p=Ty[y_idx, :])
    z_next = np.random.choice(Tz.shape[1], p=Tz[z_idx, :])
    e_next = np.random.choice(Te.shape[1], p=Te[e_idx, :])
    return y_next, z_next, e_next

# ---------- Taylor rule and Fisher equation ----------
def taylor_nominal_gross(pi_t, epsilon_t, R_ss=R_bar, phi=phi_taylor):
    """Nominal gross rate from Taylor rule: 1+i_{t+1} = R_ss * (1+pi_t)^phi * exp(epsilon_t)."""
    return R_ss * ((1.0 + pi_t) ** phi) * np.exp(epsilon_t)

def fisher_real_gross(R_nom, pi_t):
    """Real gross rate from Fisher: 1+r_t = (1+i_t)/(1+pi_t) = R_nom/(1+pi_t). Returns 1+r_t."""
    denom = 1.0 + pi_t
    if hasattr(denom, 'clamp'):
        denom = denom.clamp(min=1e-8)
    elif denom < 1e-8:
        denom = 1e-8
    return R_nom / denom

def real_rate_from_taylor_fisher(pi_t, epsilon_t, R_ss=R_bar, phi=phi_taylor):
    """Real rate r_t from Taylor + Fisher: R_nom = Taylor(pi_t, epsilon_t), then 1+r_t = R_nom/(1+pi_t), return r_t."""
    R_nom = taylor_nominal_gross(pi_t, epsilon_t, R_ss, phi)
    one_plus_r = R_nom / (1.0 + pi_t + 1e-20)
    return one_plus_r - 1.0

# ---------- NK: Y_t from resource constraint; Phillips curve residual (for loss penalty) ----------
def Y_from_C_Pi(C_agg, Pi_t, theta_rot=theta_rotemberg):
    """Y_t = C_t + (theta/2) Pi_t^2 Y_t  =>  Y_t = C_agg / (1 - (theta/2)*Pi_t^2). Pi_t = inflation (gross or net)."""
    denom = 1.0 - (theta_rot / 2.0) * (Pi_t ** 2)
    if hasattr(denom, 'clamp'):
        denom = denom.clamp(min=1e-8)
    elif denom <= 1e-8:
        denom = 1e-8
    return C_agg / denom

def phillips_residual(Pi_t, Pi_tp1, w_t, z_t, Y_t, Y_tp1, R_t, eps=epsilon, theta_rot=theta_rotemberg):
    """Residual of NK Phillips curve: Pi_t(1+Pi_t) = (eps/theta)(w_t/z_t - (eps-1)/eps) + (Y_{t+1}/Y_t)*Pi_{t+1}(1+Pi_{t+1})/(1+R_t)."""
    lhs = Pi_t * (1 + Pi_t)
    mc_term = (eps / theta_rot) * (w_t / z_t - (eps - 1) / eps)
    fwd_term = (Y_tp1 / (Y_t + 1e-20)) * (Pi_tp1 * (1 + Pi_tp1) / (1 + R_t))
    return lhs - mc_term - fwd_term

def dividend_agg(Y_t, w_t, z_t, Pi_t, theta_rot=theta_rotemberg):
    """Aggregate firm dividend: D_t = (1 - w_t/z_t)*Y_t - (theta/2)*Pi_t^2*Y_t. Per capita d_t = D_t (mass 1)."""
    return (1.0 - w_t / (z_t + 1e-20)) * Y_t - (theta_rot / 2.0) * (Pi_t ** 2) * Y_t

# %% [markdown]
# ## Simulation (household side with simplified prices)
#
# Given a policy $(c, n)(b, y, r, w)$ and a price process, we simulate paths and compute $\hat{v}_\pi$. Bond market clearing $B = \int b\, dG$ would pin down $r$ in full GE; here we use the simplified $(r_t, w_t)$ process.

# %%
def simulate_hank(T, N_agents, policy_fn, y_grid, z_grid, e_grid, Ty, Tz, Te):
    y_idx = np.random.randint(0, ny, size=N_agents)
    z_idx = np.random.randint(0, nz)
    e_idx = np.random.randint(0, ne)
    b = np.zeros(N_agents)
    r_t, w_t = r_ss, w_ss
    T_t = r_t * B_supply
    d_t = d_ss * z_grid[z_idx]
    paths = {'b': np.zeros((T+1, N_agents)), 'y': np.zeros((T+1, N_agents)), 'z': np.zeros(T+1),
             'r': np.zeros(T+1), 'w': np.zeros(T+1), 'c': np.zeros((T+1, N_agents)), 'n': np.zeros((T+1, N_agents))}
    paths['b'][0], paths['y'][0] = b, y_grid[y_idx]
    paths['z'][0], paths['r'][0], paths['w'][0] = z_grid[z_idx], r_t, w_t
    paths['c'][0], paths['n'][0] = np.nan, np.nan
    for t in range(T):
        y_val = y_grid[y_idx]
        c_t, b_next, n_t = policy_fn(b, y_val, r_t, w_t, d_t, T_t)
        paths['c'][t], paths['n'][t] = c_t, n_t
        paths['r'][t], paths['w'][t] = r_t, w_t
        b = b_next
        paths['b'][t+1] = b
        _, z_idx, e_idx = draw_next_state(y_idx[0], z_idx, e_idx, Ty, Tz, Te)
        y_idx = np.array([draw_next_state(y_idx[i], z_idx, e_idx, Ty, Tz, Te)[0] for i in range(N_agents)])
        paths['y'][t+1] = y_grid[y_idx]
        r_t, w_t, T_t, d_t = prices_next(r_t, w_t, z_idx, e_idx, Tz, Te, z_grid, e_grid)
        paths['z'][t+1] = z_grid[z_idx]
    paths['r'][T], paths['w'][T] = r_t, w_t
    paths['c'][T], _, paths['n'][T] = policy_fn(b, paths['y'][T], r_t, w_t, d_t, T_t)
    v_hat = np.sum([(beta**t) * np.mean(u_separable(paths['c'][t], paths['n'][t])) for t in range(T)])
    return paths, v_hat

# %%
def policy_fn(b, y, r, w, d, T):
    return policy_placeholder(b, y, r, w, d, T, c_frac=0.6, n_frac=0.5)

paths, v_hat = simulate_hank(100, 500, policy_fn, y_grid, z_grid, e_grid, Ty, Tz, Te)
print("v̂_π =", v_hat)
print("Mean c, n:", np.nanmean(paths['c']), np.nanmean(paths['n']))

# %% [markdown]
# ## SRL / SPG for one-account HANK
#
# Policy parameters $\theta$ represent **consumption** and **labor** on a grid over $(b, y, r, w)$ (no $z_t$). We maximize $L(\theta) = \mathbb{E}[\sum_t \beta^t u(c_t, n_t)]$ with **stop-gradient** on $(r_t, w_t)$ so households take prices as given. In the full model, $(r, w)$ would be determined by bond/labor market clearing and the NK block (Phillips curve + Taylor rule); here we keep the simplified price process.

# %% [markdown]
# ## Summary
#
# - **Model:** One-account HANK: (c, n) = π(b, y; r, w); budget c + b' = (1+r)b + w·y·n + d − T; separable u(c,n).
# - **r, w from market clearing:** (r, w) are solved by aggregate market clearing (bond: $\sum b\, dG = B$; labour: supply = demand), not random. We choose grid (ir, iw) that minimizes clearing residuals each period.
# - **Tax and dividend:** $T_t = r_t B$; individuals receive $d_t = (1 - w_t/z_t)Y_t - \frac{\theta}{2}\Pi_t^2 Y_t$ and pay tax $T_t$.
# - **State dynamics:** y, z from Ty, Tz; distribution d evolves via policy and transition.
# - **SRL/SPG:** Maximize L(θ) with gradient-stop on (r, w); policy (c, n) on (b, y, r, w) grid (no z). Set `use_market_clearing=True` to solve (r, w) from clearing.

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
dtype = torch.float32

nb_spg, nr_spg, nw_spg, nz_spg = 30, 10, 10, 8
ny_spg = ny
J = nb_spg * ny_spg

b_grid_t = torch.tensor(np.linspace(b_min, b_max, nb_spg), dtype=dtype, device=device)
r_grid_t = torch.tensor(np.linspace(r_min, r_max, nr_spg), dtype=dtype, device=device)
w_grid_t = torch.tensor(np.linspace(w_min, w_max, nw_spg), dtype=dtype, device=device)
iz = np.linspace(0, nz-1, nz_spg, dtype=int)
z_grid_t = torch.tensor(z_grid[iz], dtype=dtype, device=device)
y_grid_t = torch.tensor(y_grid, dtype=dtype, device=device)
Ty_t = torch.tensor(Ty, dtype=dtype, device=device)
Tz_sub = Tz[np.ix_(iz, iz)] / Tz[np.ix_(iz, iz)].sum(axis=1, keepdims=True)
Tz_t = torch.tensor(Tz_sub, dtype=dtype, device=device)

def theta_to_cn(theta_c, theta_n):
    """θ_c, θ_n (J, nr, nw) -> c >= c_min, n in [n_min, 2]. Policy does not depend on z."""
    c = torch.nn.functional.softplus(theta_c) + c_min
    n = torch.sigmoid(theta_n) * (2.0 - n_min) + n_min
    return c, n

def init_theta_hank(b_grid_t, y_grid_t, r_grid_t, w_grid_t, c_frac=0.6, n_val=0.5, d_ss_t=0.1):
    nr, nw = len(r_grid_t), len(w_grid_t)
    theta_c = torch.zeros(J, nr, nw, dtype=dtype, device=device)
    theta_n = torch.zeros(J, nr, nw, dtype=dtype, device=device)
    for ib in range(nb_spg):
        for iy in range(ny_spg):
            j = ib * ny_spg + iy
            b = b_grid_t[ib].item()
            y = y_grid_t[iy].item()
            for ir in range(nr):
                r = r_grid_t[ir].item()
                for iw in range(nw):
                    w = w_grid_t[iw].item()
                    T = r * B_supply
                    d = d_ss_t
                    cash = (1 + r) * b + w * y * n_val + d - T
                    c_init = max(c_frac * cash, c_min)
                    theta_c[j, ir, iw] = np.log(np.exp(c_init - c_min) - 1 + 1e-8)
                    theta_n[j, ir, iw] = np.log((n_val - n_min) / (2.0 - n_val + 1e-8))
    return theta_c, theta_n

def u_torch(c_vec, n_vec):
    c_vec = torch.clamp(c_vec, min=c_min)
    n_vec = torch.clamp(n_vec, min=n_min, max=10.0)
    return (c_vec ** (1 - sigma)) / (1 - sigma) - (n_vec ** (1 + eta)) / (1 + eta)

# %%
# (r,w) either from market clearing (use_market_clearing=True) or random grid draw. SPG maximizes L(θ).
def market_clearing_residual(ir, iw, d, iz, theta_c, theta_n, b_grid_t, y_grid_t, z_grid_t, r_grid_t, w_grid_t,
                              Ty_t, nb_spg, ny_spg, theta_pc, B_supply):
    """Given (ir, iw), compute bond and labour clearing residuals (no grad). Bond: d_next @ b_vals = B; Labour: d @ n_t = Y_t/z."""
    with torch.no_grad():
        J = nb_spg * ny_spg
        r_t = r_grid_t[ir].detach(); w_t = w_grid_t[iw].detach(); z_val = z_grid_t[iz]
        T_t = r_t * B_supply
        c, n = theta_to_cn(theta_c, theta_n)
        c_t = c[:, ir, iw]; n_t = n[:, ir, iw]
        C_agg = d @ c_t
        Pi_t = torch.tensor(0.0, device=device, dtype=dtype)
        Y_t = Y_from_C_Pi(C_agg, Pi_t, theta_pc)
        d_t = dividend_agg(Y_t, w_t, z_val, Pi_t, theta_pc)
        b_vals = b_grid_t.repeat_interleave(ny_spg)
        y_vals = y_grid_t.repeat(nb_spg)
        b_next = (1 + r_t) * b_vals + w_t * y_vals * n_t + d_t - T_t - c_t
        b_next = torch.clamp(b_next, b_min, b_max)
        sigma_b = 0.5
        dist = b_next.unsqueeze(1) - b_grid_t.unsqueeze(0)
        w_b = torch.exp(-dist.pow(2) / (2 * sigma_b**2))
        w_b = w_b / (w_b.sum(dim=1, keepdim=True) + 1e-8)
        A = torch.zeros(J, J, dtype=dtype, device=device)
        for j in range(J):
            ib, iy = j // ny_spg, j % ny_spg
            for ibp in range(nb_spg):
                for iyp in range(ny_spg):
                    jp = ibp * ny_spg + iyp
                    A[jp, j] = w_b[j, ibp] * Ty_t[iy, iyp]
        d_next = (A.T @ d).detach()
        B_next = (d_next @ b_vals).item()
        N_supply = (d @ n_t).item()
        N_demand = (Y_t / (z_val + 1e-20)).item()
        res_bond = (B_next - B_supply) ** 2
        res_labour = (N_supply - N_demand) ** 2
    return res_bond + res_labour

def spg_objective_hank(theta_c, theta_n, N_traj, T_horizon, b_grid_t, y_grid_t, z_grid_t, r_grid_t, w_grid_t,
                        Ty_t, Tz_t, nb_spg, ny_spg, nz_spg, nr_spg, nw_spg, beta_t, d_ss_val=0.1, d0=None,
                        penalty_pc=0.0, eps_pc=epsilon, theta_pc=theta_rotemberg, use_market_clearing=True):
    J = nb_spg * ny_spg
    if d0 is None:
        d0 = torch.ones(J, device=device, dtype=dtype) / J
    L_list = []
    pc_penalty_list = []
    for n in range(N_traj):
        iz = np.random.randint(0, nz_spg)
        ir = 0 if use_market_clearing else np.random.randint(0, nr_spg)
        iw = 0 if use_market_clearing else np.random.randint(0, nw_spg)
        d = d0.clone()
        L_n = torch.tensor(0.0, device=device, dtype=dtype)
        pc_penalty_n = torch.tensor(0.0, device=device, dtype=dtype)
        for t in range(T_horizon):
            if use_market_clearing:
                best_loss = float('inf')
                for ir_ in range(nr_spg):
                    for iw_ in range(nw_spg):
                        loss = market_clearing_residual(ir_, iw_, d, iz, theta_c, theta_n, b_grid_t, y_grid_t, z_grid_t, r_grid_t, w_grid_t, Ty_t, nb_spg, ny_spg, theta_pc, B_supply)
                        if loss < best_loss:
                            best_loss = loss
                            ir, iw = ir_, iw_
            r_t = r_grid_t[ir].detach()
            w_t = w_grid_t[iw].detach()
            z_val = z_grid_t[iz]
            T_t = r_t * B_supply
            c, n = theta_to_cn(theta_c, theta_n)
            c_t = c[:, ir, iw]
            n_t = n[:, ir, iw]
            C_agg = (d @ c_t).detach()
            Pi_t = torch.tensor(0.0, device=device, dtype=dtype)
            Y_t = Y_from_C_Pi(C_agg, Pi_t, theta_pc)
            d_t = dividend_agg(Y_t, w_t, z_val, Pi_t, theta_pc)
            L_n = L_n + (beta_t ** t) * (d @ u_torch(c_t, n_t))
            if penalty_pc > 0:
                R_t = 1.0 + r_t
                res_pc = Pi_t * (1 + Pi_t) - (eps_pc / theta_pc) * (w_t / z_val - (eps_pc - 1) / eps_pc) - (Y_t / (Y_t + 1e-20)) * (Pi_t * (1 + Pi_t) / R_t)
                pc_penalty_n = pc_penalty_n + res_pc ** 2
            b_vals = b_grid_t.repeat_interleave(ny_spg)
            y_vals = y_grid_t.repeat(nb_spg)
            b_next = (1 + r_t) * b_vals + w_t * y_vals * n_t + d_t - T_t - c_t
            b_next = torch.clamp(b_next, b_min, b_max)
            sigma_b = 0.5
            dist = b_next.unsqueeze(1) - b_grid_t.unsqueeze(0)
            w_b = torch.exp(-dist.pow(2) / (2 * sigma_b**2))
            w_b = w_b / (w_b.sum(dim=1, keepdim=True) + 1e-8)
            A = torch.zeros(J, J, dtype=dtype, device=device)
            for j in range(J):
                ib, iy = j // ny_spg, j % ny_spg
                for ibp in range(nb_spg):
                    for iyp in range(ny_spg):
                        jp = ibp * ny_spg + iyp
                        A[jp, j] = w_b[j, ibp] * Ty_t[iy, iyp]
            d = (A.T @ d).detach()
            iz = np.random.choice(nz_spg, p=Tz_t[iz, :].detach().cpu().numpy())
            if not use_market_clearing:
                ir = np.random.randint(0, nr_spg)
                iw = np.random.randint(0, nw_spg)
        L_list.append(L_n)
        pc_penalty_list.append(pc_penalty_n)
    L_mean = torch.stack(L_list).mean()
    if penalty_pc > 0:
        L_mean = L_mean - penalty_pc * torch.stack(pc_penalty_list).mean()
    return L_mean

# %%
theta_c, theta_n = init_theta_hank(b_grid_t, y_grid_t, r_grid_t, w_grid_t)
theta_c = theta_c.requires_grad_(True)
theta_n = theta_n.requires_grad_(True)
optimizer = torch.optim.Adam([theta_c, theta_n], lr=5e-4)
N_traj, T_horizon = 24, 40
n_epochs = 150
loss_hist = []
for epoch in range(n_epochs):
    optimizer.zero_grad()
    L = spg_objective_hank(theta_c, theta_n, N_traj, T_horizon, b_grid_t, y_grid_t, z_grid_t, r_grid_t, w_grid_t,
                           Ty_t, Tz_t, nb_spg, ny_spg, nz_spg, nr_spg, nw_spg, beta, penalty_pc=penalty_phillips)
    loss_hist.append(L.item())
    (-L).backward()
    optimizer.step()
    if (epoch + 1) % 30 == 0:
        print(f"Epoch {epoch+1}, L(θ) = {L.item():.6f}")
plt.figure(figsize=(8, 4))
plt.plot(loss_hist)
plt.xlabel('Epoch')
plt.ylabel('L(θ)')
plt.title('One-account HANK SRL/SPG (household block)')
plt.grid(True, alpha=0.3)
plt.show()
